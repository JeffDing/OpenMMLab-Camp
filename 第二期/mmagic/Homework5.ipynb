# %% [markdown]
# ## 图生图——ControlNet-Canny

# %%
import cv2
import numpy as np
import mmcv
from mmengine import Config 
 
from PIL import Image
from mmagic.registry import MODELS
from mmagic.utils import register_all_modules
 
register_all_modules()
 
cfg = Config.fromfile('configs/controlnet/controlnet-canny.py')
controlnet = MODELS.build(cfg.model).cuda()
 
# 输入Canny边缘图
control_url = 'data/maopi.jpg' # 输入的图像路径
control_img = mmcv.imread(control_url)
control = cv2.canny(control_img, 100,200)
control = control[:, :, None]
control = np.concatenate([control]* 3, axis=2)
control = Image.fromarray(control)
 
prompt = 'Room with blue walls and a yellow ceiling.'
output_dict = controlnet.infer(prompt, control=control)
samples = output_dict['samples']
for idx, sample in enumerate(samples):
    sample.save(f'sample_{idx}.png')

controls = output_dict['controls']

for idx, control in enumerate(controls):
    control.save( f'control_{idx}.png')
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:703 in urlopen                  │
# │                                                                                                  │
# │    700 │   │   │   │   self._prepare_proxy(conn)                                                 │
# │    701 │   │   │                                                                                 │
# │    702 │   │   │   # Make the request on the httplib connection object.                          │
# │ ❱  703 │   │   │   httplib_response = self._make_request(                                        │
# │    704 │   │   │   │   conn,                                                                     │
# │    705 │   │   │   │   method,                                                                   │
# │    706 │   │   │   │   url,                                                                      │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:386 in _make_request            │
# │                                                                                                  │
# │    383 │   │                                                                                     │
# │    384 │   │   # Trigger any extra validation we need to do.                                     │
# │    385 │   │   try:                                                                              │
# │ ❱  386 │   │   │   self._validate_conn(conn)                                                     │
# │    387 │   │   except (SocketTimeout, BaseSSLError) as e:                                        │
# │    388 │   │   │   # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.         │
# │    389 │   │   │   self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)               │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:1042 in _validate_conn          │
# │                                                                                                  │
# │   1039 │   │                                                                                     │
# │   1040 │   │   # Force connect early to allow us to validate the connection.                     │
# │   1041 │   │   if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`          │
# │ ❱ 1042 │   │   │   conn.connect()                                                                │
# │   1043 │   │                                                                                     │
# │   1044 │   │   if not conn.is_verified:                                                          │
# │   1045 │   │   │   warnings.warn(                                                                │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connection.py:419 in connect                      │
# │                                                                                                  │
# │   416 │   │   ):                                                                                 │
# │   417 │   │   │   context.load_default_certs()                                                   │
# │   418 │   │                                                                                      │
# │ ❱ 419 │   │   self.sock = ssl_wrap_socket(                                                       │
# │   420 │   │   │   sock=conn,                                                                     │
# │   421 │   │   │   keyfile=self.key_file,                                                         │
# │   422 │   │   │   certfile=self.cert_file,                                                       │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:449 in ssl_wrap_socket               │
# │                                                                                                  │
# │   446 │   │   )                                                                                  │
# │   447 │                                                                                          │
# │   448 │   if send_sni:                                                                           │
# │ ❱ 449 │   │   ssl_sock = _ssl_wrap_socket_impl(                                                  │
# │   450 │   │   │   sock, context, tls_in_tls, server_hostname=server_hostname                     │
# │   451 │   │   )                                                                                  │
# │   452 │   else:                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:493 in _ssl_wrap_socket_impl         │
# │                                                                                                  │
# │   490 │   │   return SSLTransport(sock, ssl_context, server_hostname)                            │
# │   491 │                                                                                          │
# │   492 │   if server_hostname:                                                                    │
# │ ❱ 493 │   │   return ssl_context.wrap_socket(sock, server_hostname=server_hostname)              │
# │   494 │   else:                                                                                  │
# │   495 │   │   return ssl_context.wrap_socket(sock)                                               │
# │   496                                                                                            │
# │                                                                                                  │
# │ /usr/lib/python3.8/ssl.py:500 in wrap_socket                                                     │
# │                                                                                                  │
# │    497 │   │   │   │   │   server_hostname=None, session=None):                                  │
# │    498 │   │   # SSLSocket class handles server_hostname encoding before it calls                │
# │    499 │   │   # ctx._wrap_socket()                                                              │
# │ ❱  500 │   │   return self.sslsocket_class._create(                                              │
# │    501 │   │   │   sock=sock,                                                                    │
# │    502 │   │   │   server_side=server_side,                                                      │
# │    503 │   │   │   do_handshake_on_connect=do_handshake_on_connect,                              │
# │                                                                                                  │
# │ /usr/lib/python3.8/ssl.py:1040 in _create                                                        │
# │                                                                                                  │
# │   1037 │   │   │   │   │   if timeout == 0.0:                                                    │
# │   1038 │   │   │   │   │   │   # non-blocking                                                    │
# │   1039 │   │   │   │   │   │   raise ValueError("do_handshake_on_connect should not be specifie  │
# │ ❱ 1040 │   │   │   │   │   self.do_handshake()                                                   │
# │   1041 │   │   │   except (OSError, ValueError):                                                 │
# │   1042 │   │   │   │   self.close()                                                              │
# │   1043 │   │   │   │   raise                                                                     │
# │                                                                                                  │
# │ /usr/lib/python3.8/ssl.py:1309 in do_handshake                                                   │
# │                                                                                                  │
# │   1306 │   │   try:                                                                              │
# │   1307 │   │   │   if timeout == 0.0 and block:                                                  │
# │   1308 │   │   │   │   self.settimeout(None)                                                     │
# │ ❱ 1309 │   │   │   self._sslobj.do_handshake()                                                   │
# │   1310 │   │   finally:                                                                          │
# │   1311 │   │   │   self.settimeout(timeout)                                                      │
# │   1312                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.8/dist-packages/requests/adapters.py:486 in send                          │
# │                                                                                                  │
# │   483 │   │   │   timeout = TimeoutSauce(connect=timeout, read=timeout)                          │
# │   484 │   │                                                                                      │
# │   485 │   │   try:                                                                               │
# │ ❱ 486 │   │   │   resp = conn.urlopen(                                                           │
# │   487 │   │   │   │   method=request.method,                                                     │
# │   488 │   │   │   │   url=url,                                                                   │
# │   489 │   │   │   │   body=request.body,                                                         │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:787 in urlopen                  │
# │                                                                                                  │
# │    784 │   │   │   elif isinstance(e, (SocketError, HTTPException)):                             │
# │    785 │   │   │   │   e = ProtocolError("Connection aborted.", e)                               │
# │    786 │   │   │                                                                                 │
# │ ❱  787 │   │   │   retries = retries.increment(                                                  │
# │    788 │   │   │   │   method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]           │
# │    789 │   │   │   )                                                                             │
# │    790 │   │   │   retries.sleep()                                                               │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/util/retry.py:550 in increment                    │
# │                                                                                                  │
# │   547 │   │   elif error and self._is_read_error(error):                                         │
# │   548 │   │   │   # Read retry?                                                                  │
# │   549 │   │   │   if read is False or not self._is_method_retryable(method):                     │
# │ ❱ 550 │   │   │   │   raise six.reraise(type(error), error, _stacktrace)                         │
# │   551 │   │   │   elif read is not None:                                                         │
# │   552 │   │   │   │   read -= 1                                                                  │
# │   553                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/packages/six.py:769 in reraise                    │
# │                                                                                                  │
# │    766 │   │   │   if value is None:                                                             │
# │    767 │   │   │   │   value = tp()                                                              │
# │    768 │   │   │   if value.__traceback__ is not tb:                                             │
# │ ❱  769 │   │   │   │   raise value.with_traceback(tb)                                            │
# │    770 │   │   │   raise value                                                                   │
# │    771 │   │   finally:                                                                          │
# │    772 │   │   │   value = None                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:703 in urlopen                  │
# │                                                                                                  │
# │    700 │   │   │   │   self._prepare_proxy(conn)                                                 │
# │    701 │   │   │                                                                                 │
# │    702 │   │   │   # Make the request on the httplib connection object.                          │
# │ ❱  703 │   │   │   httplib_response = self._make_request(                                        │
# │    704 │   │   │   │   conn,                                                                     │
# │    705 │   │   │   │   method,                                                                   │
# │    706 │   │   │   │   url,                                                                      │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:386 in _make_request            │
# │                                                                                                  │
# │    383 │   │                                                                                     │
# │    384 │   │   # Trigger any extra validation we need to do.                                     │
# │    385 │   │   try:                                                                              │
# │ ❱  386 │   │   │   self._validate_conn(conn)                                                     │
# │    387 │   │   except (SocketTimeout, BaseSSLError) as e:                                        │
# │    388 │   │   │   # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.         │
# │    389 │   │   │   self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)               │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:1042 in _validate_conn          │
# │                                                                                                  │
# │   1039 │   │                                                                                     │
# │   1040 │   │   # Force connect early to allow us to validate the connection.                     │
# │   1041 │   │   if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`          │
# │ ❱ 1042 │   │   │   conn.connect()                                                                │
# │   1043 │   │                                                                                     │
# │   1044 │   │   if not conn.is_verified:                                                          │
# │   1045 │   │   │   warnings.warn(                                                                │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/connection.py:419 in connect                      │
# │                                                                                                  │
# │   416 │   │   ):                                                                                 │
# │   417 │   │   │   context.load_default_certs()                                                   │
# │   418 │   │                                                                                      │
# │ ❱ 419 │   │   self.sock = ssl_wrap_socket(                                                       │
# │   420 │   │   │   sock=conn,                                                                     │
# │   421 │   │   │   keyfile=self.key_file,                                                         │
# │   422 │   │   │   certfile=self.cert_file,                                                       │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:449 in ssl_wrap_socket               │
# │                                                                                                  │
# │   446 │   │   )                                                                                  │
# │   447 │                                                                                          │
# │   448 │   if send_sni:                                                                           │
# │ ❱ 449 │   │   ssl_sock = _ssl_wrap_socket_impl(                                                  │
# │   450 │   │   │   sock, context, tls_in_tls, server_hostname=server_hostname                     │
# │   451 │   │   )                                                                                  │
# │   452 │   else:                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py:493 in _ssl_wrap_socket_impl         │
# │                                                                                                  │
# │   490 │   │   return SSLTransport(sock, ssl_context, server_hostname)                            │
# │   491 │                                                                                          │
# │   492 │   if server_hostname:                                                                    │
# │ ❱ 493 │   │   return ssl_context.wrap_socket(sock, server_hostname=server_hostname)              │
# │   494 │   else:                                                                                  │
# │   495 │   │   return ssl_context.wrap_socket(sock)                                               │
# │   496                                                                                            │
# │                                                                                                  │
# │ /usr/lib/python3.8/ssl.py:500 in wrap_socket                                                     │
# │                                                                                                  │
# │    497 │   │   │   │   │   server_hostname=None, session=None):                                  │
# │    498 │   │   # SSLSocket class handles server_hostname encoding before it calls                │
# │    499 │   │   # ctx._wrap_socket()                                                              │
# │ ❱  500 │   │   return self.sslsocket_class._create(                                              │
# │    501 │   │   │   sock=sock,                                                                    │
# │    502 │   │   │   server_side=server_side,                                                      │
# │    503 │   │   │   do_handshake_on_connect=do_handshake_on_connect,                              │
# │                                                                                                  │
# │ /usr/lib/python3.8/ssl.py:1040 in _create                                                        │
# │                                                                                                  │
# │   1037 │   │   │   │   │   if timeout == 0.0:                                                    │
# │   1038 │   │   │   │   │   │   # non-blocking                                                    │
# │   1039 │   │   │   │   │   │   raise ValueError("do_handshake_on_connect should not be specifie  │
# │ ❱ 1040 │   │   │   │   │   self.do_handshake()                                                   │
# │   1041 │   │   │   except (OSError, ValueError):                                                 │
# │   1042 │   │   │   │   self.close()                                                              │
# │   1043 │   │   │   │   raise                                                                     │
# │                                                                                                  │
# │ /usr/lib/python3.8/ssl.py:1309 in do_handshake                                                   │
# │                                                                                                  │
# │   1306 │   │   try:                                                                              │
# │   1307 │   │   │   if timeout == 0.0 and block:                                                  │
# │   1308 │   │   │   │   self.settimeout(None)                                                     │
# │ ❱ 1309 │   │   │   self._sslobj.do_handshake()                                                   │
# │   1310 │   │   finally:                                                                          │
# │   1311 │   │   │   self.settimeout(timeout)                                                      │
# │   1312                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.8/dist-packages/diffusers/utils/hub_utils.py:311 in _get_model_file       │
# │                                                                                                  │
# │   308 │   │   │   │   )                                                                          │
# │   309 │   │   try:                                                                               │
# │   310 │   │   │   # 2. Load model file as usual                                                  │
# │ ❱ 311 │   │   │   model_file = hf_hub_download(                                                  │
# │   312 │   │   │   │   pretrained_model_name_or_path,                                             │
# │   313 │   │   │   │   filename=weights_name,                                                     │
# │   314 │   │   │   │   cache_dir=cache_dir,                                                       │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/huggingface_hub/utils/_validators.py:120 in _inner_fn     │
# │                                                                                                  │
# │   117 │   │   if check_use_auth_token:                                                           │
# │   118 │   │   │   kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=ha   │
# │   119 │   │                                                                                      │
# │ ❱ 120 │   │   return fn(*args, **kwargs)                                                         │
# │   121 │                                                                                          │
# │   122 │   return _inner_fn  # type: ignore                                                       │
# │   123                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/huggingface_hub/file_download.py:1364 in hf_hub_download  │
# │                                                                                                  │
# │   1361 │   │   with temp_file_manager() as temp_file:                                            │
# │   1362 │   │   │   logger.info("downloading %s to %s", url, temp_file.name)                      │
# │   1363 │   │   │                                                                                 │
# │ ❱ 1364 │   │   │   http_get(                                                                     │
# │   1365 │   │   │   │   url_to_download,                                                          │
# │   1366 │   │   │   │   temp_file,                                                                │
# │   1367 │   │   │   │   proxies=proxies,                                                          │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/huggingface_hub/file_download.py:505 in http_get          │
# │                                                                                                  │
# │    502 │   if resume_size > 0:                                                                   │
# │    503 │   │   headers["Range"] = "bytes=%d-" % (resume_size,)                                   │
# │    504 │                                                                                         │
# │ ❱  505 │   r = _request_wrapper(                                                                 │
# │    506 │   │   method="GET",                                                                     │
# │    507 │   │   url=url,                                                                          │
# │    508 │   │   stream=True,                                                                      │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/huggingface_hub/file_download.py:442 in _request_wrapper  │
# │                                                                                                  │
# │    439 │   │   return response                                                                   │
# │    440 │                                                                                         │
# │    441 │   # 3. Exponential backoff                                                              │
# │ ❱  442 │   return http_backoff(                                                                  │
# │    443 │   │   method=method,                                                                    │
# │    444 │   │   url=url,                                                                          │
# │    445 │   │   max_retries=max_retries,                                                          │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/huggingface_hub/utils/_http.py:212 in http_backoff        │
# │                                                                                                  │
# │   209 │   │   │   │   kwargs["data"].seek(io_obj_initial_pos)                                    │
# │   210 │   │   │                                                                                  │
# │   211 │   │   │   # Perform request and return if status_code is not in the retry list.          │
# │ ❱ 212 │   │   │   response = session.request(method=method, url=url, **kwargs)                   │
# │   213 │   │   │   if response.status_code not in retry_on_status_codes:                          │
# │   214 │   │   │   │   return response                                                            │
# │   215                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/requests/sessions.py:587 in request                       │
# │                                                                                                  │
# │   584 │   │   │   "allow_redirects": allow_redirects,                                            │
# │   585 │   │   }                                                                                  │
# │   586 │   │   send_kwargs.update(settings)                                                       │
# │ ❱ 587 │   │   resp = self.send(prep, **send_kwargs)                                              │
# │   588 │   │                                                                                      │
# │   589 │   │   return resp                                                                        │
# │   590                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/requests/sessions.py:701 in send                          │
# │                                                                                                  │
# │   698 │   │   start = preferred_clock()                                                          │
# │   699 │   │                                                                                      │
# │   700 │   │   # Send the request                                                                 │
# │ ❱ 701 │   │   r = adapter.send(request, **kwargs)                                                │
# │   702 │   │                                                                                      │
# │   703 │   │   # Total elapsed time of the request (approximately)                                │
# │   704 │   │   elapsed = preferred_clock() - start                                                │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/requests/adapters.py:501 in send                          │
# │                                                                                                  │
# │   498 │   │   │   )                                                                              │
# │   499 │   │                                                                                      │
# │   500 │   │   except (ProtocolError, OSError) as err:                                            │
# │ ❱ 501 │   │   │   raise ConnectionError(err, request=request)                                    │
# │   502 │   │                                                                                      │
# │   503 │   │   except MaxRetryError as e:                                                         │
# │   504 │   │   │   if isinstance(e.reason, ConnectTimeoutError):                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py:122 in               │
# │ build_from_cfg                                                                                   │
# │                                                                                                  │
# │   119 │   │   │   │   │   issubclass(obj_cls, ManagerMixin):  # type: ignore                     │
# │   120 │   │   │   │   obj = obj_cls.get_instance(**args)  # type: ignore                         │
# │   121 │   │   │   else:                                                                          │
# │ ❱ 122 │   │   │   │   obj = obj_cls(**args)  # type: ignore                                      │
# │   123 │   │   │                                                                                  │
# │   124 │   │   │   if (inspect.isclass(obj_cls) or inspect.isfunction(obj_cls)                    │
# │   125 │   │   │   │   │   or inspect.ismethod(obj_cls)):                                         │
# │                                                                                                  │
# │ /gemini/code/temp/mmagic/mmagic/models/archs/wrapper.py:90 in __init__                           │
# │                                                                                                  │
# │    87 │   │   self._from_config = from_config                                                    │
# │    88 │   │                                                                                      │
# │    89 │   │   if from_pretrained is not None:                                                    │
# │ ❱  90 │   │   │   self.model = module_cls.from_pretrained(from_pretrained, *args,                │
# │    91 │   │   │   │   │   │   │   │   │   │   │   │   │   **kwargs)                              │
# │    92 │   │   │   # weight has been initialized from pretrained, therefore we                    │
# │    93 │   │   │   # `self._is_init` as True manually                                             │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/diffusers/models/modeling_utils.py:579 in from_pretrained │
# │                                                                                                  │
# │   576 │   │   │   │   │   │   raise e                                                            │
# │   577 │   │   │   │   │   pass                                                                   │
# │   578 │   │   │   if model_file is None:                                                         │
# │ ❱ 579 │   │   │   │   model_file = _get_model_file(                                              │
# │   580 │   │   │   │   │   pretrained_model_name_or_path,                                         │
# │   581 │   │   │   │   │   weights_name=_add_variant(WEIGHTS_NAME, variant),                      │
# │   582 │   │   │   │   │   cache_dir=cache_dir,                                                   │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/diffusers/utils/hub_utils.py:356 in _get_model_file       │
# │                                                                                                  │
# │   353 │   │   │   │   " offline mode at 'https://huggingface.co/docs/diffusers/installation#of   │
# │   354 │   │   │   )                                                                              │
# │   355 │   │   except EnvironmentError:                                                           │
# │ ❱ 356 │   │   │   raise EnvironmentError(                                                        │
# │   357 │   │   │   │   f"Can't load the model for '{pretrained_model_name_or_path}'. If you wer   │
# │   358 │   │   │   │   "'https://huggingface.co/models', make sure you don't have a local direc   │
# │   359 │   │   │   │   f"Otherwise, make sure '{pretrained_model_name_or_path}' is the correct    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# OSError: Can't load the model for 'runwayml/stable-diffusion-v1-5'. If you were trying to load it from
# 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make
# sure 'runwayml/stable-diffusion-v1-5' is the correct path to a directory containing a file named
# diffusion_pytorch_model.bin
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py:122 in               │
# │ build_from_cfg                                                                                   │
# │                                                                                                  │
# │   119 │   │   │   │   │   issubclass(obj_cls, ManagerMixin):  # type: ignore                     │
# │   120 │   │   │   │   obj = obj_cls.get_instance(**args)  # type: ignore                         │
# │   121 │   │   │   else:                                                                          │
# │ ❱ 122 │   │   │   │   obj = obj_cls(**args)  # type: ignore                                      │
# │   123 │   │   │                                                                                  │
# │   124 │   │   │   if (inspect.isclass(obj_cls) or inspect.isfunction(obj_cls)                    │
# │   125 │   │   │   │   │   or inspect.ismethod(obj_cls)):                                         │
# │                                                                                                  │
# │ /gemini/code/temp/mmagic/mmagic/models/editors/controlnet/controlnet.py:75 in __init__           │
# │                                                                                                  │
# │    72 │   │   │   │    data_preprocessor=dict(type='DataPreprocessor'),                          │
# │    73 │   │   │   │    init_cfg: Optional[dict] = None,                                          │
# │    74 │   │   │   │    attention_injection=False):                                               │
# │ ❱  75 │   │   super().__init__(vae, text_encoder, tokenizer, unet, scheduler,                    │
# │    76 │   │   │   │   │   │    test_scheduler, dtype, enable_xformers,                           │
# │    77 │   │   │   │   │   │    noise_offset_weight, tomesd_cfg, data_preprocessor,               │
# │    78 │   │   │   │   │   │    init_cfg)                                                         │
# │                                                                                                  │
# │ /gemini/code/temp/mmagic/mmagic/models/editors/stable_diffusion/stable_diffusion.py:91 in        │
# │ __init__                                                                                         │
# │                                                                                                  │
# │    88 │   │   │   │   'fp32', None                                                               │
# │    89 │   │   │   ], ('dtype must be one of \'fp32\', \'fp16\', \'bf16\' or None.')              │
# │    90 │   │                                                                                      │
# │ ❱  91 │   │   self.vae = build_module(vae, MODELS, default_args=default_args)                    │
# │    92 │   │   self.unet = build_module(unet, MODELS)  # NOTE: initialize unet as fp32            │
# │    93 │   │   self.scheduler = build_module(scheduler, DIFFUSION_SCHEDULERS)                     │
# │    94 │   │   if test_scheduler is None:                                                         │
# │                                                                                                  │
# │ /gemini/code/temp/mmagic/mmagic/models/utils/model_utils.py:253 in build_module                  │
# │                                                                                                  │
# │   250 │   │   Any: The built module.                                                             │
# │   251 │   """                                                                                    │
# │   252 │   if isinstance(module, dict):                                                           │
# │ ❱ 253 │   │   return builder.build(module, *args, **kwargs)                                      │
# │   254 │   elif isinstance(module, nn.Module):                                                    │
# │   255 │   │   return module                                                                      │
# │   256 │   else:                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/registry.py:548 in build                │
# │                                                                                                  │
# │   545 │   │   │   >>> cfg = dict(type='ResNet', depth=50)                                        │
# │   546 │   │   │   >>> model = MODELS.build(cfg)                                                  │
# │   547 │   │   """                                                                                │
# │ ❱ 548 │   │   return self.build_func(cfg, *args, **kwargs, registry=self)                        │
# │   549 │                                                                                          │
# │   550 │   def _add_child(self, registry: 'Registry') -> None:                                    │
# │   551 │   │   """Add a child for a registry.                                                     │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py:250 in               │
# │ build_model_from_cfg                                                                             │
# │                                                                                                  │
# │   247 │   │   ]                                                                                  │
# │   248 │   │   return Sequential(*modules)                                                        │
# │   249 │   else:                                                                                  │
# │ ❱ 250 │   │   return build_from_cfg(cfg, registry, default_args)                                 │
# │   251                                                                                            │
# │   252                                                                                            │
# │   253 def build_scheduler_from_cfg(                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py:144 in               │
# │ build_from_cfg                                                                                   │
# │                                                                                                  │
# │   141 │   │   │   # Normal TypeError does not print class name.                                  │
# │   142 │   │   │   cls_location = '/'.join(                                                       │
# │   143 │   │   │   │   obj_cls.__module__.split('.'))  # type: ignore                             │
# │ ❱ 144 │   │   │   raise type(e)(                                                                 │
# │   145 │   │   │   │   f'class `{obj_cls.__name__}` in '  # type: ignore                          │
# │   146 │   │   │   │   f'{cls_location}.py: {e}')                                                 │
# │   147                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# OSError: class `AutoencoderKL` in mmagic/models/archs.py: Can't load the model for
# 'runwayml/stable-diffusion-v1-5'. If you were trying to load it from 'https://huggingface.co/models', make sure you
# don't have a local directory with the same name. Otherwise, make sure 'runwayml/stable-diffusion-v1-5' is the
# correct path to a directory containing a file named diffusion_pytorch_model.bin
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:13                                                                                   │
# │                                                                                                  │
# │   10 register_all_modules()                                                                      │
# │   11                                                                                             │
# │   12 cfg = Config.fromfile('configs/controlnet/controlnet-canny.py')                             │
# │ ❱ 13 controlnet = MODELS.build(cfg.model).cuda()                                                 │
# │   14                                                                                             │
# │   15 # 输入Canny边缘图                                                                           │
# │   16 control_url = 'data/maopi.jpg' # 输入的图像路径                                             │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/registry.py:548 in build                │
# │                                                                                                  │
# │   545 │   │   │   >>> cfg = dict(type='ResNet', depth=50)                                        │
# │   546 │   │   │   >>> model = MODELS.build(cfg)                                                  │
# │   547 │   │   """                                                                                │
# │ ❱ 548 │   │   return self.build_func(cfg, *args, **kwargs, registry=self)                        │
# │   549 │                                                                                          │
# │   550 │   def _add_child(self, registry: 'Registry') -> None:                                    │
# │   551 │   │   """Add a child for a registry.                                                     │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py:250 in               │
# │ build_model_from_cfg                                                                             │
# │                                                                                                  │
# │   247 │   │   ]                                                                                  │
# │   248 │   │   return Sequential(*modules)                                                        │
# │   249 │   else:                                                                                  │
# │ ❱ 250 │   │   return build_from_cfg(cfg, registry, default_args)                                 │
# │   251                                                                                            │
# │   252                                                                                            │
# │   253 def build_scheduler_from_cfg(                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py:144 in               │
# │ build_from_cfg                                                                                   │
# │                                                                                                  │
# │   141 │   │   │   # Normal TypeError does not print class name.                                  │
# │   142 │   │   │   cls_location = '/'.join(                                                       │
# │   143 │   │   │   │   obj_cls.__module__.split('.'))  # type: ignore                             │
# │ ❱ 144 │   │   │   raise type(e)(                                                                 │
# │   145 │   │   │   │   f'class `{obj_cls.__name__}` in '  # type: ignore                          │
# │   146 │   │   │   │   f'{cls_location}.py: {e}')                                                 │
# │   147                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# OSError: class `ControlStableDiffusion` in mmagic/models/editors/controlnet/controlnet.py: class `AutoencoderKL` in
# mmagic/models/archs.py: Can't load the model for 'runwayml/stable-diffusion-v1-5'. If you were trying to load it
# from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise,
# make sure 'runwayml/stable-diffusion-v1-5' is the correct path to a directory containing a file named
# diffusion_pytorch_model.bin
